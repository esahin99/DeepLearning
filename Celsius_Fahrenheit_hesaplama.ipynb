# %% [markdown]
# <a href="https://colab.research.google.com/github/MehmeTTEmre/deep_learning/blob/main/Celsius_Fahrenheit_hesaplama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bu kodumda tek node'lu bir sinir ağı ile derin öğrenme yaparak makinaya istediğimiz bir celsius derecesinin kaç fahrenheit olduğunu hesaplattım.

# %% [markdown]
# ##İlgili kütüphaneleri import ediyorum

# %%
import tensorflow as tf                                                                     
import numpy as np

# %% [markdown]
# ##makinanın derin öğrenme yapabilmesi için birkaç input-output değerlerini giriyorum

# %%
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %% [markdown]
# ##Girdiğimiz celsius değerlerinin kaç fahrenheite eşit olduğunu göstermek için yazılmış bir for döngüsü

# %%
for c, f in zip(celsius, fahrenheit):                                                 
  print(f"{c} celcius > {f} fahrenheit")
# Out:
# -40.0 celcius > -40.0 fahrenheit
# -10.0 celcius > 14.0 fahrenheit
# 0.0 celcius > 32.0 fahrenheit
# 8.0 celcius > 46.0 fahrenheit
# 15.0 celcius > 59.0 fahrenheit
# 22.0 celcius > 72.0 fahrenheit
# 38.0 celcius > 100.0 fahrenheit

# %% [markdown]
# ##tek node lu sinir ağımızı oluşturdum

# %%
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# ##oluşturulan sinir ağının modelini görmek için yazılan kod

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="mean_squared_error", optimizer=tf.keras.optimizers.Adam(0.1))

# %% [markdown]
# ##modelimizi 500 adımda eğitiyoruz ve eğitimin sonucunu saklamak için history değişkenine atıyorum

# %%
history = model.fit(celsius, fahrenheit, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4917
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.3887
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 7.2869
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1864
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0872
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9893
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.8926
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7971
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7028
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.6097
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.5178
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.4271
# ...

# %% [markdown]
# ##eğitimin sonuçlarını grafiksel olarak görebilmek için ilgili kütüphaneleri import ettim

# %%
import matplotlib.pyplot as plt

# %%
plt.xlabel("Epoch Number")
plt.ylabel("Loss Magnitude")
plt.plot(history.history["loss"])

# %% [markdown]
# ##eğittiğim bu sinir ağına 81 celsius değerini girerek sonucun kaç fahrenheit olduğunu makinaya tahmin ettirdim ve 171.5 gibi sonuca oldukça yakın bir sonuç tahmin etti

# %%
model.predict([81.0])
# Out:
# array([[177.57846]], dtype=float32)

# %% [markdown]
# ##en son olarak eğittiğim sinir ağının oluşturduğu fonksiyonu burada görebiliyorum

# %%
model.get_weights()
# Out:
# [array([[1.7981654]], dtype=float32), array([31.927067], dtype=float32)]
